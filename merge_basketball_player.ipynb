# %%
import pandas as pd

df_champion_player = pd.read_csv("/Users/alism/Desktop/basketball_final2/championPlayer.csv")
df_best_player = pd.read_csv("/Users/alism/Desktop/basketball_final2/bestPlayer.csv")
df_mvp= pd.read_csv("/Users/alism/Desktop/basketball_final2/mvp.csv")
df_best_player.shape
# Out:
# (150, 12)

# %%
df_final = pd.concat([df_champion_player,df_mvp, df_best_player], ignore_index=True)



df_final.to_csv("df_final.csv", index=False)
df_final
# player_df=df_final[["player_id","player_name","height_cm","weight_kg","age","experience_years"]].copy()
#
#
# Out:
#      player_id              player_name  age  rank  season  height_cm  \
# 0    gilgesh01  Shai Gilgeous-Alexander   26   NaN    2025        198
# 1    willija06           Jalen Williams   23   NaN    2025        198
# 2     dortlu01            Luguentz Dort   25   NaN    2025        193
# 3    harteis01       Isaiah Hartenstein   26   NaN    2025        213
# 4    wallaca01            Cason Wallace   21   NaN    2025        193
# ..         ...                      ...  ...   ...     ...        ...
# 345  siakapa01            Pascal Siakam   25  21.0    2020        203
# 346  sextoco01            Collin Sexton   21  22.0    2020        190
# 347  gilgesh01  Shai Gilgeous-Alexander   21  23.0    2020        198
# 348  warretj01              T.J. Warren   26  24.0    2020        203
# 349  dinwisp01        Spencer Dinwiddie   26  25.0    2020        196
#
#      weight_kg  experience_years                            positions  \
# ...

# %%
# position_df= df_final[["player_id", "positions"]].copy()
#
#
# position_df.to_csv("position_df.csv", index=False)
# position_df

# %%
# data = {
#     "ID_group": [1, 2, 3],
#     "groupName": ["MJT", "LC", "TS"]
# }
#
#
# group_df = pd.DataFrame(data)
#
# group_df
# group_df.to_csv("group_df.csv", index=False)

# %%
# seasons_df= df_final[["player_id", "rank","season","groupName"]].copy()
#
# seasons_df["ID_seasons"] = seasons_df["season"] % 100
# seasons_df
# seasons_df.to_csv("seasons_df.csv", index=False)
# seasons_df
